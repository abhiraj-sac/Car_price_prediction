# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv("Used Car Dataset.csv")
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)
df
# Out:
#                                                car_name registration_year  \
# 0                       2017 Mercedes-Benz S-Class S400            Jul-17
# 1     2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                          2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                              2019 Kia Seltos GTX Plus            Dec-19
# 4                       2019 Skoda Superb LK 1.8 TSI AT            Aug-19
# ...                                                 ...               ...
# 1548           2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549                 2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550                           2017 Honda WR-V i-VTEC S            Jun-17
# 1551           2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552                        2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
df.head(3)
# Out:
#                                             car_name registration_year  \
# 0                    2017 Mercedes-Benz S-Class S400            Jul-17
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                       2018 BMW X1 sDrive 20d xLine            Sep-18
#
#   insurance_validity fuel_type  seats  kms_driven   ownsership transmission  \
# 0      Comprehensive    Petrol      5       56000  First Owner    Automatic
# 1      Comprehensive    Petrol      5       30615  First Owner    Automatic
# 2      Comprehensive    Diesel      5       24000  First Owner    Automatic
#
#   manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0               2017           7.81      2996.0          2996.0       333.0
# 1               2020          17.40       999.0           999.0      9863.0
# 2               2018          20.68      1995.0          1995.0       188.0
#
#    price(in lakhs)
# 0            63.75
# 1             8.99
# ...

# %%
df.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
df['torque(Nm)'].mode()[0]
df['torque(Nm)']=df['torque(Nm)'].fillna(8180.0)
df.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df['max_power(bhp)'].mode()[0]
df['max_power(bhp)']=df['max_power(bhp)'].fillna(1197.0)
df.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df['mileage(kmpl)'].mode()[0]
df['mileage(kmpl)']=df['mileage(kmpl)'].fillna(18.9)
df.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            3
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df['engine(cc)'].mode()[0]
df['engine(cc)']=df['engine(cc)'].fillna(18.9)
df.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df.describe()
# Out:
#               seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count   1553.000000    1553.000000    1553.000000  1.553000e+03
# mean      91.480361   52841.931101     236.506104  1.469014e+10
# std     2403.424060   40067.800347     585.476015  2.183526e+11
# min        4.000000     620.000000       7.810000  5.000000e+00
# 25%        5.000000   30000.000000      16.350000  1.197000e+03
# 50%        5.000000   49134.000000      18.900000  1.462000e+03
# 75%        5.000000   70000.000000      22.000000  1.995000e+03
# max    67000.000000  810000.000000    3996.000000  3.258640e+12
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count    1.553000e+03  1.553000e+03      1553.000000
# mean     1.469014e+10  1.422428e+04       166.141494
# std      2.183526e+11  9.653825e+04      3478.855090
# min      5.000000e+00  5.000000e+00         1.000000
# 25%      1.197000e+03  4.000000e+02         4.660000
# 50%      1.462000e+03  1.173000e+03         7.140000
# ...

# %%
df[df['price(in lakhs)'] > 50000]
# Out:
#                        car_name registration_year insurance_validity  \
# 173   2011 Ford Figo Petrol EXI            Jun-11      Comprehensive
# 193   2011 Ford Figo Petrol EXI            Jun-11      Comprehensive
# 1277   2009 Maruti Alto 800 LXi            May-09      Comprehensive
#
#      fuel_type  seats  kms_driven    ownsership transmission  \
# 173     Petrol      5       66717  Second Owner       Manual
# 193     Petrol      5       66717  Second Owner       Manual
# 1277    Petrol      5       44002   Third Owner       Manual
#
#      manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 173                2011         1196.0        70.0            70.0
# 193                2011         1196.0        70.0            70.0
# 1277               2009           19.7       796.0           796.0
#
#       torque(Nm)  price(in lakhs)
# 173        102.0          70000.0
# 193        102.0          70000.0
# 1277       463.0          95000.0

# %%
# sns.boxplot(df['price(in lakhs)'])
df.drop(index=[173,193,1277],inplace=True)
df[df['price(in lakhs)'] > 50000]
# Out:
# Empty DataFrame
# Columns: [car_name, registration_year, insurance_validity, fuel_type, seats, kms_driven, ownsership, transmission, manufacturing_year, mileage(kmpl), engine(cc), max_power(bhp), torque(Nm), price(in lakhs)]
# Index: []

# %%
sns.boxplot(df['price(in lakhs)'])
# Out:
# <Axes: >

# %%
# df[df['price(in lakhs)'] < 40]
# sns.boxplot(df[df['price(in lakhs)'] < 40]['price(in lakhs)'])
# df[df['price(in lakhs)'] < 40][['price(in lakhs)']]
# sns.boxplot(df[df['price(in lakhs)'] < 40][['price(in lakhs)']])

# %%
df.corr(numeric_only=True)
# Out:
#                     seats  kms_driven  mileage(kmpl)  engine(cc)  \
# seats            1.000000   -0.045745       0.003066   -0.002371
# kms_driven      -0.045745    1.000000      -0.101287   -0.041473
# mileage(kmpl)    0.003066   -0.101287       1.000000    0.309814
# engine(cc)      -0.002371   -0.041473       0.309814    1.000000
# max_power(bhp)  -0.002371   -0.041473       0.309814    1.000000
# torque(Nm)      -0.005308    0.059292      -0.002100   -0.009450
# price(in lakhs)  0.003336   -0.220891       0.044171   -0.051252
#
#                  max_power(bhp)  torque(Nm)  price(in lakhs)
# seats                 -0.002371   -0.005308         0.003336
# kms_driven            -0.041473    0.059292        -0.220891
# mileage(kmpl)          0.309814   -0.002100         0.044171
# engine(cc)             1.000000   -0.009450        -0.051252
# max_power(bhp)         1.000000   -0.009450        -0.051252
# torque(Nm)            -0.009450    1.000000        -0.031056
# ...

# %%
df.head(4)
df.drop(columns=['registration_year'],axis=1,inplace=True)

# %%
df.head(4)
df['car_brand'] = df['car_name'].str.split().str[2:].str.join(' ')
df['main_brand'] = df['car_name'].str.split().str[1:2].str.join(' ')

# %%
# Checking the duplicates 
df.duplicated().sum()
# Out:
# 420

# %%
df.head(3)
# Out:
#                                             car_name insurance_validity  \
# 0                    2017 Mercedes-Benz S-Class S400      Comprehensive
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI      Comprehensive
# 2                       2018 BMW X1 sDrive 20d xLine      Comprehensive
#
#   fuel_type  seats  kms_driven   ownsership transmission manufacturing_year  \
# 0    Petrol      5       56000  First Owner    Automatic               2017
# 1    Petrol      5       30615  First Owner    Automatic               2020
# 2    Diesel      5       24000  First Owner    Automatic               2018
#
#    mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)  \
# 0           7.81      2996.0          2996.0       333.0            63.75
# 1          17.40       999.0           999.0      9863.0             8.99
# 2          20.68      1995.0          1995.0       188.0            23.75
#
#                                car_brand     main_brand
# ...

# %%
df['insurance_validity'].unique()
# Out:
# array(['Comprehensive', 'Third Party insurance', 'Zero Dep',
#        'Third Party', 'Petrol', 'Not Available'], dtype=object)

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', '5 Seats'], dtype=object)

# %%
plt.scatter(df['fuel_type'],df['price(in lakhs)'])
plt.show()

# %%
df[df['fuel_type'] == '5 Seats']
df.drop(index=[798,818],inplace=True)

# %%
plt.scatter(df['fuel_type'],df['price(in lakhs)'])
plt.show()

# %%
df['ownsership'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner', '2993 cc', '1461 cc',
#        '998 cc', '1995 cc', '1451 cc', '1998 cc', '1498 cc', '1497 cc',
#        '1996 cc', '1950 cc', 'Fifth Owner', '1199 cc', '1248 cc',
#        '999 cc', '1197 cc', '1984 cc', '2999 cc', '1968 cc'], dtype=object)

# %%
curpt_rows = ~df['ownsership'].isin(['First Owner', 'Second Owner', 'Third Owner'])

# %%
df[curpt_rows]
# Out:
#                                                car_name  \
# 116                     2017 BMW 7 Series 730Ld M Sport
# 136                     2017 BMW 7 Series 730Ld M Sport
# 170       2014 Nissan Terrano XV 110 PS Limited Edition
# 190       2014 Nissan Terrano XV 110 PS Limited Edition
# 210                 2023 Hyundai i20 N-Line N8 DCT BSVI
# 213                    2017 BMW X1 sDrive20d Expedition
# 228                       2020 MG Hector Plus Smart DCT
# 231                    2017 BMW X1 sDrive20d Expedition
# 233                    2017 BMW X1 sDrive20d Expedition
# 234                    2017 BMW X1 sDrive20d Expedition
# 235                    2017 BMW X1 sDrive20d Expedition
# 248                       2020 MG Hector Plus Smart DCT
# 251                    2017 BMW X1 sDrive20d Expedition
# 253                    2017 BMW X1 sDrive20d Expedition
# 254                    2017 BMW X1 sDrive20d Expedition
# 255                    2017 BMW X1 sDrive20d Expedition
# ...

# %%
df = df.drop(df[curpt_rows].index)
# df.reset_index(inplace = True)

# %%
df['ownsership'].value_counts().plot(kind='barh')
plt.show()
# df[df['ownsership'] == 'Fifth Owner']

# %%
df['ownsership'] = df['ownsership'].map({'First Owner':1,'Second Owner':2,'Third Owner':3})

# %%
# df

# %%
df['main_brand'].value_counts().plot(kind='bar')
plt.plot()
# Out:
# []

# %%
brand_country_map = {
    'Maruti': 'India',
    'Hyundai': 'South Korea',
    'Honda': 'Japan',
    'Mercedes-Benz': 'Germany',
    'Toyota': 'Japan',
    'BMW': 'Germany',
    'Tata': 'India',
    'Audi': 'Germany',
    'Mahindra': 'India',
    'Ford': 'United States',
    'Renault': 'France',
    'Volkswagen': 'Germany',
    'Kia': 'South Korea',
    'Nissan': 'Japan',
    'Skoda': 'Czech Republic',
    'Jeep': 'United States',
    'MG': 'United Kingdom',
    'Volvo': 'Sweden',
    'Jaguar': 'United Kingdom',
    'Land': 'United Kingdom',
    'Datsun': 'Japan',
    'Mitsubishi': 'Japan',
    'Porsche': 'Germany',
    'Mini': 'United Kingdom',
    'Isuzu': 'Japan',
    'Lexus': 'Japan',
    'Fiat': 'Italy',
    'Lamborghini': 'Italy'
}

df['origin_country'] = df['main_brand'].map(brand_country_map)
df.head()
# Out:
#                                             car_name insurance_validity  \
# 0                    2017 Mercedes-Benz S-Class S400      Comprehensive
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI      Comprehensive
# 2                       2018 BMW X1 sDrive 20d xLine      Comprehensive
# 3                           2019 Kia Seltos GTX Plus      Comprehensive
# 4                    2019 Skoda Superb LK 1.8 TSI AT      Comprehensive
#
#   fuel_type  seats  kms_driven  ownsership transmission manufacturing_year  \
# 0    Petrol      5       56000           1    Automatic               2017
# 1    Petrol      5       30615           1    Automatic               2020
# 2    Diesel      5       24000           1    Automatic               2018
# 3    Petrol      5       18378           1       Manual               2019
# 4    Petrol      5       44900           1    Automatic               2019
#
#    mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)  \
# ...

# %%
df['origin_country'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['fuel_type'].value_counts().plot(kind='bar')
plt.show()

# %%
# plt.scatter(df['fuel_type'],df['price(in lakhs)'])
# plt.show()

# %%
df['engine(cc)'].plot(kind='box')
corr_eng = df['engine(cc)'] > 2500

# %%
df = df.drop(df[corr_eng].index)
df['engine(cc)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df['transmission'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='transmission'>

# %%
# df['max_power(bhp)'].unique()
df.drop(columns=['max_power(bhp)'],inplace=True)

# %%
# df['max_power(bhp)'].value_counts().plot(kind='bar')

# %%
# df = df.drop(df.index[df['max_power(bhp)'] >= 2000])
# df.info()

# %%
# df['max_power(bhp)'].value_counts().plot(kind='bar')

# %%
# df[df['max_power(bhp)'] >= 1000]

# %%
df['torque(Nm)']
# Out:
# 1        9863.0
# 2         188.0
# 3       13808.0
# 4       17746.0
# 5         887.0
#          ...
# 1546      887.0
# 1547     8663.0
# 1550      887.0
# 1551       75.0
# 1552     8314.0
# Name: torque(Nm), Length: 1273, dtype: float64

# %%
curpt_rows3 = df[df['torque(Nm)'] > 20000]

# %%
curpt_rows3
# Out:
#                                                car_name  \
# 20                          2021 MG Gloster Savvy 6-Str
# 40                          2021 MG Gloster Savvy 6-Str
# 64         2021 Mercedes-Benz C-Class Progressive C 200
# 68                  2023 BMW 5 Series 530i M Sport BSVI
# 84         2021 Mercedes-Benz C-Class Progressive C 200
# 88                  2023 BMW 5 Series 530i M Sport BSVI
# 203        2021 Mercedes-Benz C-Class Progressive C 200
# 205        2019 Mercedes-Benz C-Class Progressive C 200
# 206                         2021 MG Gloster Savvy 6-Str
# 208        2018 Land Rover Discovery Sport Petrol SE 7S
# 215        2020 Mercedes-Benz C-Class Progressive C 200
# 216                         2021 MG Gloster Savvy 6-Str
# 236                         2021 MG Gloster Savvy 6-Str
# 268                          2011 Hyundai i20 1.2 Magna
# 286                         2020 Hyundai Venue E Diesel
# 287       2017 Land Rover Discovery Sport Petrol HSE 7S
# ...

# %%
df = df.drop(curpt_rows3.index)

# %%
counts = df['torque(Nm)']

plt.boxplot(counts,vert=False)
plt.show()

# %%
curpt_rows4 = df[df['price(in lakhs)'] > 17]
curpt_rows4.count()
# Out:
# car_name              188
# insurance_validity    188
# fuel_type             188
# seats                 188
# kms_driven            188
# ownsership            188
# transmission          188
# manufacturing_year    188
# mileage(kmpl)         188
# engine(cc)            188
# torque(Nm)            188
# price(in lakhs)       188
# car_brand             188
# main_brand            188
# origin_country        188
# dtype: int64

# %%
df = df.drop(curpt_rows4.index)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1030 entries, 1 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1030 non-null   object
#  1   insurance_validity  1030 non-null   object
#  2   fuel_type           1030 non-null   object
#  3   seats               1030 non-null   int64
#  4   kms_driven          1030 non-null   int64
#  5   ownsership          1030 non-null   int64
#  6   transmission        1030 non-null   object
#  7   manufacturing_year  1030 non-null   object
#  8   mileage(kmpl)       1030 non-null   float64
#  9   engine(cc)          1030 non-null   float64
#  10  torque(Nm)          1030 non-null   float64
#  11  price(in lakhs)     1030 non-null   float64
#  12  car_brand           1030 non-null   object
#  13  main_brand          1030 non-null   object
#  14  origin_country      1030 non-null   object
# dtypes: float64(4), int64(3), object(8)
# ...

# %%
df['transmission'] = df['transmission'].replace({'Manual' : 1,
                                                   'Automatic' : 2
                                                    })

df['fuel_type'] = df['fuel_type'].replace({'Petrol' : 3,
                                                'Diesel' : 2,
                                                'CNG' : 1
                                               })

# Drop the 'car_brand' and the 'main_brand' columns:

df = df.drop(['car_name'],axis=1)

df.head(10)
# Out:
#        insurance_validity  fuel_type  seats  kms_driven  ownsership  \
# 1           Comprehensive          3      5       30615           1
# 3           Comprehensive          3      5       18378           1
# 5   Third Party insurance          3      5       42000           1
# 6           Comprehensive          3      5       36739           1
# 7           Comprehensive          3      5       76000           1
# 9           Comprehensive          3      5       28783           1
# 10          Comprehensive          3      5       40000           1
# 11          Comprehensive          3      5       17382           1
# 12  Third Party insurance          2      5      120000           1
# 13          Comprehensive          3      5       17000           1
#
#     transmission manufacturing_year  mileage(kmpl)  engine(cc)  torque(Nm)  \
# 1              2               2020          17.40       999.0      9863.0
# ...

# %%
num_col = df.select_dtypes(include=['int64', 'float64']).columns

# %%
cat_col= df.select_dtypes(exclude=['int64', 'float64']).columns

# %%
corr_matrix = df[num_col].corr()
sns.heatmap(corr_matrix,annot=True)
plt.figure(figsize=(12,12))
plt.show()

# %%
sns.pairplot(df,hue='transmission')
plt.show()
# Out:
# C:\Users\Abhi\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['transmission'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
X = df.drop('price(in lakhs)',axis=1)
Y = df['price(in lakhs)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
# df.drop(columns=['insurance_validity','origin_country','car_brand','main_brand'],axis=1,inplace=True)
df.drop(columns=['torque(Nm)','seats'],axis=1,inplace=True)

# %%
# df = pd.get_dummies(cdf,columns=['insurance_validity','origin_country'])
# cdf
final = df.copy()
final
df
X = df.drop('price(in lakhs)',axis=1)
Y = df['price(in lakhs)']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
# conduct an RFE so we can pick the best features that can predict the target:
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
from sklearn.metrics import r2_score
estimator = LinearRegression()
selected_features_list = []
r2_score_list = []

for k in range(1, 23
              ):
    RFE_selector = RFE(estimator=estimator, n_features_to_select=k, step=1)
    RFE_selector.fit(x_train, y_train)
    
    selected_features = x_train.columns[RFE_selector.support_].tolist()
    selected_features_list.append(selected_features)
    
    select_x_train = RFE_selector.transform(x_train)
    select_x_test = RFE_selector.transform(x_test)
    
    estimator.fit(select_x_train, y_train)
    predict = estimator.predict(select_x_test)
    
    r2score = r2_score(y_test, predict)
    r2_score_list.append(r2score)

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, 23), r2_score_list)
plt.title('R2 Score vs. Number of Features Selected')
plt.xlabel('Number of Features Selected')
plt.ylabel('R2 Score')
plt.show()

# %%
RFE_selector = RFE(estimator=estimator, n_features_to_select=23, step=1)
RFE_selector.fit(x_train, y_train)

selected_features = RFE_selector.get_support()
selected_feature_names = x_train.columns[selected_features]

selected_feature_names
# Out:
# Index(['fuel_type', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)'],
#       dtype='object')

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'rmse is {rmse} \n mse is {mse} \n r2 is {r2}')
# Out:
# rmse is 2.0380252505327436
#  mse is 4.153546921809052
#  r2 is 0.604728621054219

# %%
y_pred = model.predict([[2,64000,1,1,2018,21.70,1498.0]])
y_pred
# Out:
# C:\Users\Abhi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8.04231986])

# %%
df[df['mileage(kmpl)'] == 21.70]
# Out:
#       fuel_type  kms_driven  ownsership  transmission manufacturing_year  \
# 163           2       59870           1             1               2016
# 183           2       59870           1             1               2016
# 291           2       64000           1             1               2018
# 310           2       64000           1             1               2018
# 1052          2       65000           1             1               2017
# 1055          2       90000           1             1               2018
# 1131          2      810000           1             1               2020
# 1272          2       78000           1             1               2015
# 1296          3       26638           1             1               2020
#
#       mileage(kmpl)  engine(cc)  price(in lakhs)
# 163            21.7      1498.0             4.95
# 183            21.7      1498.0             4.95
# 291            21.7      1498.0             7.99
# ...

# %%
import pickle 
pickle.dump(model,open('model.pkl','wb'))
